# %%
# %sql
CREATE CATALOG IF NOT EXISTS ecommerce;
USE CATALOG ecommerce;

CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW SCHEMAS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>bronze</td></tr><tr><td>default</td></tr><tr><td>gold</td></tr><tr><td>information_schema</td></tr><tr><td>silver</td></tr></tbody></table></div>

# %%
# %sql
-- Managed table

CREATE TABLE IF NOT EXISTS bronze.events (
    event_time TIMESTAMP,
    user_id STRING,
    product_id STRING,
    price DOUBLE
)
USING DELTA;

CREATE TABLE IF NOT EXISTS silver.events (
    event_time TIMESTAMP,
    user_id STRING,
    product_id STRING,
    price DOUBLE
)
USING DELTA;

CREATE TABLE IF NOT EXISTS gold.products (
    product_id STRING,
    product_name STRING,
    revenue DOUBLE,
    purchases INT
)
USING DELTA;

# %%
# %sql
-- Grants read-only (SELECT) access on the `gold.products` table to the account users group.
GRANT SELECT
ON TABLE gold.products
TO `account users`;

-- Grants full privileges on the `silver` schema to the user `katarushreya1729@gmail.com`.

GRANT ALL PRIVILEGES
ON SCHEMA silver
TO `tanujkumawat3008@gmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW GRANTS ON SCHEMA silver;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Principal</th><th>ActionType</th><th>ObjectType</th><th>ObjectKey</th></tr></thead><tbody><tr><td>tanujkumawat3008@gmail.com</td><td>ALL PRIVILEGES</td><td>SCHEMA</td><td>ecommerce.silver</td></tr></tbody></table></div>

# %%
# %sql
SHOW GRANTS ON TABLE gold.products;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Principal</th><th>ActionType</th><th>ObjectType</th><th>ObjectKey</th></tr></thead><tbody><tr><td>account users</td><td>SELECT</td><td>TABLE</td><td>ecommerce.gold.products</td></tr></tbody></table></div>

# %%
# %sql
-- revoke all the privileges on the silver schema from the user`katarushreya1729@gmail.com`.

REVOKE ALL PRIVILEGES
ON SCHEMA silver
FROM `tanujkumawat3008@gmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE VIEW gold.top_products AS
SELECT
    product_name,
    revenue,
    purchases
FROM gold.products
WHERE purchases > 10
ORDER BY revenue DESC
LIMIT 100;

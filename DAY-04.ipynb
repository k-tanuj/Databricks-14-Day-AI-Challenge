# %%
# Reloading October data:
from pyspark.sql.types import StructType, StructField, TimestampType, StringType, LongType, DoubleType

schema = StructType([
    StructField("event_time", TimestampType(), True),
    StructField("event_type", StringType(), True),
    StructField("product_id", LongType(), True),
    StructField("category_id", LongType(), True),
    StructField("category_code", StringType(), True),
    StructField("brand", StringType(), True),
    StructField("price", DoubleType(), True),
    StructField("user_id", LongType(), True),
    StructField("user_session", StringType(), True)
])

events = spark.read.csv(
    "/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv",
    header=True,
    schema=schema
)

# %%
# Choosing Delta location inside volume:
delta_path = "/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct"

events.write.format("delta") \
    .mode("overwrite") \
    .save(delta_path)

# %%
# %fs ls /Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1768232826090</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00000-4092837b-1778-443b-9598-0be5a3d6b84e.c000.snappy.parquet</td><td>part-00000-4092837b-1778-443b-9598-0be5a3d6b84e.c000.snappy.parquet</td><td>34095145</td><td>1768232651000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00001-ebc0f680-e499-4b6a-9b9b-665bc3bba1e0.c000.snappy.parquet</td><td>part-00001-ebc0f680-e499-4b6a-9b9b-665bc3bba1e0.c000.snappy.parquet</td><td>31651988</td><td>1768232656000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00002-403426c3-9112-41f4-91ee-c2d22d88a544.c000.snappy.parquet</td><td>part-00002-403426c3-9112-41f4-91ee-c2d22d88a544.c000.snappy.parquet</td><td>31833415</td><td>1768232652000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00003-4f30947d-db38-411b-8b3a-833a83695ec3.c000.snappy.parquet</td><td>part-00003-4f30947d-db38-411b-8b3a-833a83695ec3.c000.snappy.parquet</td><td>32537240</td><td>1768232651000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00004-559f0d83-9811-47e6-a09e-363239a72868.c000.snappy.parquet</td><td>part-00004-559f0d83-9811-47e6-a09e-363239a72868.c000.snappy.parquet</td><td>33620729</td><td>1768232651000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00005-ff5ffd07-3806-4016-952f-d3a0ba40619a.c000.snappy.parquet</td><td>part-00005-ff5ffd07-3806-4016-952f-d3a0ba40619a.c000.snappy.parquet</td><td>33562202</td><td>1768232652000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00006-f74c87ec-4d0d-46ce-b2ea-0dee572ae1cd.c000.snappy.parquet</td><td>part-00006-f74c87ec-4d0d-46ce-b2ea-0dee572ae1cd.c000.snappy.parquet</td><td>31716159</td><td>1768232656000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00007-58291c06-e42a-4b14-b855-0c281202fa39.c000.snappy.parquet</td><td>part-00007-58291c06-e42a-4b14-b855-0c281202fa39.c000.snappy.parquet</td><td>32931407</td><td>1768232655000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00008-1a36474d-cb8e-4996-9f40-4ce01a04e4fe.c000.snappy.parquet</td><td>part-00008-1a36474d-cb8e-4996-9f40-4ce01a04e4fe.c000.snappy.parquet</td><td>32967143</td><td>1768232657000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00009-38993ed8-03e2-4ce9-8e3a-5d090002da78.c000.snappy.parquet</td><td>part-00009-38993ed8-03e2-4ce9-8e3a-5d090002da78.c000.snappy.parquet</td><td>35763200</td><td>1768232655000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00010-adf8470f-3c28-477e-9bbd-95d885a0c36a.c000.snappy.parquet</td><td>part-00010-adf8470f-3c28-477e-9bbd-95d885a0c36a.c000.snappy.parquet</td><td>33492351</td><td>1768232651000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00011-150eaedd-b46d-4960-a5ee-1046948d9d92.c000.snappy.parquet</td><td>part-00011-150eaedd-b46d-4960-a5ee-1046948d9d92.c000.snappy.parquet</td><td>33190617</td><td>1768232656000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00012-39aa25f0-125e-4b87-9425-2f34584c3e91.c000.snappy.parquet</td><td>part-00012-39aa25f0-125e-4b87-9425-2f34584c3e91.c000.snappy.parquet</td><td>33905102</td><td>1768232656000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/events_oct/part-00013-f3c30a81-18ac-4545-957c-8428193bab9e.c000.snappy.parquet</td><td>part-00013-f3c30a81-18ac-4545-957c-8428193bab9 ...

# %%
# creating managed delta table
events.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("events_table")

# %%
# checking the table
spark.sql("SELECT COUNT(*) FROM events_table").show()
# Out:
# +--------+
# |COUNT(*)|
# +--------+
# |42448764|
# +--------+

# %%
# %sql
SELECT current_catalog(), current_schema();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_catalog()</th><th>current_schema()</th></tr></thead><tbody><tr><td>workspace</td><td>default</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TABLE events_delta
USING DELTA
AS
SELECT *
FROM workspace.default.events_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW TABLES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>events_delta</td><td>false</td></tr><tr><td>default</td><td>events_table</td><td>false</td></tr></tbody></table></div>

# %%
try:
    wrong_schema = spark.createDataFrame(
        [("a", "b", "c")],
        ["x", "y", "z"]
    )
    
    wrong_schema.write.format("delta") \
        .mode("append") \
        .save(delta_path)

except Exception as e:
    print("Schema enforcement triggered:")
    print(e)
# Out:
# Schema enforcement triggered:
# name 'delta_path' is not defined

# %%
# checking duplicate entry
events.write.format("delta") \
    .mode("append") \
    .save(delta_path)

print("After first append:", spark.read.format("delta").load(delta_path).count())

events.write.format("delta") \
    .mode("append") \
    .save(delta_path)

print("After second append:", spark.read.format("delta").load(delta_path).count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-5578529009886047>, line 2
#       1 # checking duplicate entry
# ----> 2 events.write.format("delta") \
#       3     .mode("append") \
#       4     .save(delta_path)
#       6 print("After first append:", spark.read.format("delta").load(delta_path).count())
#       8 events.write.format("delta") \
#       9     .mode("append") \
#      10     .save(delta_path)
#
# NameError: name 'events' is not defined

# %%
data = [("iPhone", 999), ("Samsung", 799), ("MacBook", 1299)]
df = spark.createDataFrame(data, ["product", "price"])
df.show()
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# | iPhone|  999|
# |Samsung|  799|
# |MacBook| 1299|
# +-------+-----+

# %%
df.filter(df.price > 1000).show()
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# |MacBook| 1299|
# +-------+-----+

# %%
df.printSchema
# Out:
# <bound method DataFrame.printSchema of DataFrame[product: string, price: bigint]>
